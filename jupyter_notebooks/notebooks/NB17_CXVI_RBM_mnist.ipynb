# %% [markdown]
# # Notebook 17: Energy-based Generative Models for MNIST

# %% [markdown]
# ## Learning Goal
# The goal of this notebook is to familiarize readers with various energy-based generative models including: Restricted Boltzmann Machines (RBMs) with Gaussian and Bernoulli units, Deep Boltzmann Machines (DBMs), as well as techniques for training these model including contrastive divergence (CD) and persistent constrastive divergence (PCD). We will also discuss how to generate new examples (commonly called fantasy particles in the ML literature). The notebook also introduces the [Paysage](https://github.com/drckf/paysage) package from [UnLearn.AI](https://unlearn.ai/) for quickly building and training these models..
#
# ## Overview
# In this notebook, we study the MNIST dataset using generative models.
#
# Let us adopt a different perspective on the MNIST dataset. Generative models, as the name suggests, are useful to generate brand new data (images) by learning how to imitate the ones from a given data set. If you wish, they can be regarded as a kind of "creative ML". This is achieved by extracting/learning a set of features which represent the backbone of the entire data and are thus definitive for the particular dataset. These features are encoded in the weights of the model.
#
# Mathematically speaking, generative models are designed and trained to learn an approximation for the probability distribution that generated the data. Intuitively, this task is much more complex and sophisticated than the image recognition task. Therefore, we shall approach the problem in a number of steps of increasing complexity. For a more detailed discussion on the theory, we invite the reader to check out Secs. XV and XVI of the review.
#
# Below, we analyze four different generative models: the Hopfield Model, a Restricted Boltzmann Machine (RBM), a regularized RMB with sparse weights, and a Deep Boltzmann Machine (DBM). In all these cases, we first set up and train the models. After that, we compare the results. Last, we open up the black box of each model and visualise a set of features it learned.
#
# ## Setting up Paysage
#
# In this notebook, we use an open-source `python` package for energy-based models, called [paysage](https://github.com/drckf/paysage). Paysage requires `python>3.5`; we recommend using the package with an [Anaconda](https://www.continuum.io/downloads) environment.
#
# To install paysage:
#
# * clone or download the [github repo](https://github.com/drckf/paysage)
# * activate an Anaconda3 environment
# * navigate to the directory which contains the paysage files
# * and execute
# ```
# pip install .
# ```
#
# Documentation for paysage is available under [https://github.com/drckf/paysage/tree/master/docs](https://github.com/drckf/paysage/tree/master/docs).
#
# By default, computations in paysage are performed using `numpy`/`numexpr`/`numba` on the CPU. If you have installed [PyTorch](https://pytorch.org), then you can switch to the `pytorch` backend by changing the setting in `paysage/backends/config.json` to `pytorch`.
#
# Let us set up the required packages for this notebook by importing paysage.

# %%
from __future__ import print_function, division
import os
import paysage
import numpy as np
import pandas as pd

# for Boltzmann machines
from paysage import preprocess as pre
from paysage.layers import BernoulliLayer, GaussianLayer
from paysage.models import BoltzmannMachine
from paysage import batch
from paysage import fit
from paysage import optimizers
from paysage import samplers
from paysage import backends as be
from paysage import schedules
from paysage import penalties as pen

# fix random seed to ensure deterministic behavior
np.random.seed(137)
be.set_seed(137)

# %% [markdown]
# ## Obtaining the MNIST dataset
#
# As we mentioned in the introduction, we use the MNIST dataset of handwritten digits to study the Hopfield model and various variants of RBMs.
#
# The MNIST dataset comprises $70000$ handwritten digits, each of which comes in a square image, divided into a $28\times 28$ pixel grid. Every pixel can take on $256$ nuances of the grey colour, interpolating between white and black, and hence each data point assumes any value in the set $\{0,1,\dots,255\}$. There are $10$ categories in the problem, corresponding to the ten digits. In previous notebooks, we formulated a classification task for the MNIST dataset, and studied it using discriminative supervised learning: Logistic Regression and Deep Neural Networks.
#
#
# This dataset can be fetched using paysage from the web as an `HDF5` file. For this, you should
#
# * navigate to the directory in which you cloned/downloaded paysage
# * navigate further into the `/examples/mnist/` directory which contains the file `download_mnist.py`.
# * from the terminal, run the command
# ```
# python3 /examples/mnist/download_mnist.py
# ```
#
# This file contains keys `train/images`, `train/labels`, `test/images`, and `test/labels` and is compressed to about 15 Mb in size.
#
# As our first step, we will set up the paths to the data and shuffle the dataset. The shuffled dataset will not be compressed (for faster reading during training) so it will be about 56 Mb in size.
#
# _Why shuffle the data?_ - Training with stochastic gradient descent means we will be using small minibatches of data (maybe 50 examples) to compute the gradient at each step. If the data have an order, then the estimates for the gradients computed from the minibatches will be biased. Shuffling the data ensures that the gradient estimates are unbiased (though still noisy).

# %%
# path to the mnist.h5 to be read. this way will look for the file in the same directory as the notebook.
mnist_path = "./mnist.h5" #os.path.join(paysage_path, "examples", "mnist", "mnist.h5")
# path to where the the shuffled mnist.h5 will be saved.
shuffled_mnist_path = "./shuffled_mnist.h5" #os.path.join(paysage_path, "examples", "mnist", "shuffled_mnist.h5")

print("path to mnist data:")
print(mnist_path)

if not os.path.exists(mnist_path):
    raise IOError("{} does not exist. run mnist/download_mnist.py to fetch from the web".format(mnist_path))
    
if not os.path.exists(shuffled_mnist_path):
    batch.DataShuffler(mnist_path, shuffled_mnist_path, complevel=0).shuffle()
# Out:
# path to mnist data:
# ./mnist.h5

# %% [markdown]
# ### Processing the Data
#
# Next, we create a `data` generator, which splits the data into a training and validation sets, and separates them into minibatches of size `batch_size`. Before we begin training, we set `data` into training mode.
#
# To monitor the progress of performance metrics during training, we define the variable `performance` which tells Paysage to measure the reconstruction error from the validation set. Possible metrics include the reconstruction error (used in this example) and metrics related to difference in energy of random samples and samples from the model (see [`metrics.md`](https://github.com/drckf/paysage/blob/master/docs/metrics.md) in Paysage documentation for a complete list).

# %%
##### set up minibatch data generator
# batch size
batch_size=100 
transform = pre.Transformation(pre.binarize_color)

# create data generator object with minibathces
samples = be.float_tensor(pd.read_hdf(shuffled_mnist_path, key='train/images').values) # value -> values
data = batch.in_memory_batch(samples, batch_size, train_fraction=0.95, transform=transform)

# reset the data generator in training mode
data.reset_generator(mode='train')

# %% [markdown]
# ### Setting up a Hopfield Model
#
# Having loaded and preprocessed the data, we now move on to construct a `hopfield` model. To do this, we use the `Model` class and with a visible `BernoulliLayer` and a hidden `GaussianLayer`. Note that the visible layer has the same size as the input data points, which is can be read off `data.ncols`. The number of hidden units is `num_hidden_units`. We also set the mean and variance of the Gaussian layer to zero and unity, respectively (the notation here is inspired by the terminology in Variational Auto Encoders).
#
# We choose to train the model with the `Adam` optimizer. To ensure convergence, we attenuate the `learning_rate` hyperparameter according to a `PowerLawDecay` schedule: `learning_rate`$(t)$ =`initial`$/(1 +$ `coefficient`$\;\times\; t)$. It will prove convenient to define the function `Adam_optimizer()` for this purpose.

# %%
##### create hopfield model
# hidden units
num_hidden_units=200 

# set up the model
vis_layer = BernoulliLayer(data.ncols)
hid_layer = GaussianLayer(num_hidden_units)
hopfield = BoltzmannMachine([vis_layer, hid_layer])

# set mean and standard deviation of hidden layer to to 0 and 1, respectively
hopfield.layers[1].set_fixed_params(['loc', 'log_var'])

# set up an optimizer method (ADAM in this case)
def ADAM_optimizer(initial,coefficient):
	# define learning rate attenuation schedule
	learning_rate=schedules.PowerLawDecay(initial=initial,coefficient=coefficient)
	# return optimizer object
	return optimizers.ADAM(stepsize=learning_rate)

# %% [markdown]
# ### Compiling and Training a Model in Paysage
#
# Next, we have compile the model. First, we initialize a `model` using the `initialize` function attribute which accepts the `data` as a required argument. We choose the initialization routine `glorot`, see discussion in review. Second, we define an optimizer calling the function `Adam_optimizer()` defined above, and store the object under the name `opt`. To define a Monte Carlo `sampler`, we use the method `from_batch` of the `SequentialMC` class, parsing the `model` and the `data`. Last, we create an `SGD` object called `trainer` to train the model using Persistent Contrastive Divergence (`pcd`) with a fixed number of `monte_carlo_steps`. We can also `monitor` the reconstruction error during training. Last, we train the model in epochs (see variable `nim_epochs`), calling the `train()` method of `trainer`. These steps are universal for shallow generative `model`'s, and it is convenient to combine them in the function `train_model()`.

# %%
# define function to compile and train model
num_epochs=20 # training epochs
monte_carlo_steps=1 # number of MC sampling steps
def train_model(model,num_epochs,monte_carlo_steps):
        # make a simple guess for the initial parameters of the model
        model.initialize(data,method='glorot_normal')
        # set optimizer
        opt=ADAM_optimizer(1E-2,1.0)
        trainer = fit.SGD(model, data)
        trainer.train(opt, num_epochs, method=fit.pcd, mcsteps=monte_carlo_steps)
# train hopfield model
train_model(hopfield,num_epochs,monte_carlo_steps)
# Out:
# Before training:
# -ReconstructionError: 1.203098
# -EnergyCoefficient: 0.134486
# -HeatCapacity: 0.434466
# -WeightSparsity: 0.335712
# -WeightSquare: 1.588543
# -KLDivergence: 0.188799
# -ReverseKLDivergence: -0.036245
#
# End of epoch 1:
# Time elapsed 10.376s
# -ReconstructionError: 0.761379
# -EnergyCoefficient: 0.265793
# -HeatCapacity: 5.619607
# -WeightSparsity: 0.269687
# -WeightSquare: 2.326731
# -KLDivergence: 0.064260
# -ReverseKLDivergence: 0.141696
#
# End of epoch 2:
# Time elapsed 11.912s
# -ReconstructionError: 0.722789
# -EnergyCoefficient: 0.272912
# -HeatCapacity: 8.225798
# -WeightSparsity: 0.269316
# -WeightSquare: 2.625770
# -KLDivergence: 0.065833
# -ReverseKLDivergence: 0.198360
#
# End of epoch 3:
# Time elapsed 10.453s
# -ReconstructionError: 0.716890
# -EnergyCoefficient: 0.284418
# -HeatCapacity: 23.707340
# -WeightSparsity: 0.268006
# -WeightSquare: 2.782513
# -KLDivergence: 0.074066
# -ReverseKLDivergence: 0.184672
#
# End of epoch 4:
# Time elapsed 10.627s
# -ReconstructionError: 0.739775
# -EnergyCoefficient: 0.396176
# -HeatCapacity: 19.287729
# -WeightSparsity: 0.268264
# -WeightSquare: 2.829444
# -KLDivergence: 0.130781
# -ReverseKLDivergence: 0.341351
#
# End of epoch 5:
# Time elapsed 10.563s
# -ReconstructionError: 0.724049
# -EnergyCoefficient: 0.339143
# -HeatCapacity: 12.315537
# -WeightSparsity: 0.273775
# -WeightSquare: 2.856990
# -KLDivergence: 0.058349
# -ReverseKLDivergence: 0.262695
#
# End of epoch 6:
# Time elapsed 9.731s
# -ReconstructionError: 0.751166
# -EnergyCoefficient: 0.384810
# -HeatCapacity: 3.298736
# -WeightSparsity: 0.278762
# -WeightSquare: 2.812199
# -KLDivergence: 0.049840
# -ReverseKLDivergence: 0.278665
#
# End of epoch 7:
# Time elapsed 11.71s
# -ReconstructionError: 0.754444
# -EnergyCoefficient: 0.326089
# -HeatCapacity: 15.169742
# -WeightSparsity: 0.279149
# -WeightSquare: 2.839225
# -KLDivergence: 0.093135
# -ReverseKLDivergence: 0.368120
#
# End of epoch 8:
# Time elapsed 8.991s
# -ReconstructionError: 0.729023
# -EnergyCoefficient: 0.234532
# -HeatCapacity: 16.935190
# -WeightSparsity: 0.278570
# -WeightSquare: 2.925098
# -KLDivergence: 0.034696
# -ReverseKLDivergence: 0.169072
#
# End of epoch 9:
# Time elapsed 8.498s
# -ReconstructionError: 0.714363
# -EnergyCoefficient: 0.216084
# -HeatCapacity: 23.731346
# -WeightSparsity: 0.271396
# -WeightSquare: 3.154351
# -KLDivergence: 0.030432
# -ReverseKLDivergence: 0.176524
#
# End of epoch 10:
# Time elapsed 10.35s
# -ReconstructionError: 0.706240
# -EnergyCoefficient: 0.330957
# -HeatCapacity: 25.450731
# -WeightSparsity: 0.269196
# -WeightSquare: 3.302357
# -KLDivergence: 0.055927
# -ReverseKLDivergence: 0.260434
#
# End of epoch 11:
# Time elapsed 7.677s
# -ReconstructionError: 0.707595
# -EnergyCoefficient: 0.318059
# -HeatCapacity: 37.306976
# -WeightSparsity: 0.262928
# -WeightSquare: 3.444946
# -KLDivergence: 0.042076
# -ReverseKLDivergence: 0.287367
#
# End of epoch 12:
# Time elapsed 8.736s
# -ReconstructionError: 0.691234
# -EnergyCoefficient: 0.283666
# -HeatCapacity: 18.561852
# -WeightSparsity: 0.255319
# -WeightSquare: 3.771627
# -KLDivergence: 0.017434
# -ReverseKLDivergence: 0.285596
#
# End of epoch 13:
# Time elapsed 7.43s
# -ReconstructionError: 0.695494
# -EnergyCoefficient: 0.291887
# -HeatCapacity: 39.799664
# -WeightSparsity: 0.252037
# -WeightSquare: 3.932966
# -KLDivergence: 0.040867
# -ReverseKLDivergence: 0.259917
#
# End of epoch 14:
# Time elapsed 7.769s
# -ReconstructionError: 0.706272
# -EnergyCoefficient: 0.388106
# -HeatCapacity: 396.554596
# -WeightSparsity: 0.251714
# -WeightSquare: 4.340692
# -KLDivergence: 0.123967
# -ReverseKLDivergence: 0.469286
#
# End of epoch 15:
# Time elapsed 7.714s
# -ReconstructionError: 0.676688
# -EnergyCoefficient: 0.228294
# -HeatCapacity: 669.960632
# -WeightSparsity: 0.256655
# -WeightSquare: 4.602409
# -KLDivergence: 0.017756
# -ReverseKLDivergence: 0.281077
#
# End of epoch 16:
# Time elapsed 8.505s
# -ReconstructionError: 0.691045
# -EnergyCoefficient: 0.283329
# -HeatCapacity: 179.633392
# -WeightSparsity: 0.256489
# -WeightSquare: 4.914822
# -KLDivergence: 0.027153
# -ReverseKLDivergence: 0.322720
#
# End of epoch 17:
# Time elapsed 10.777s
# -ReconstructionError: 0.683919
# -EnergyCoefficient: 0.256816
# -HeatCapacity: 68.924263
# -WeightSparsity: 0.261205
# -WeightSquare: 5.156081
# -KLDivergence: 0.034785
# -ReverseKLDivergence: 0.177555
#
# End of epoch 18:
# Time elapsed 9.743s
# -ReconstructionError: 0.701005
# -EnergyCoefficient: 0.397849
# -HeatCapacity: 245.421188
# -WeightSparsity: 0.262432
# -WeightSquare: 5.387504
# -KLDivergence: 0.126335
# -ReverseKLDivergence: 0.469099
#
# End of epoch 19:
# Time elapsed 8.863s
# -ReconstructionError: 0.687683
# -EnergyCoefficient: 0.307272
# -HeatCapacity: 148.875122
# -WeightSparsity: 0.263451
# -WeightSquare: 5.743479
# -KLDivergence: 0.095251
# -ReverseKLDivergence: 0.291120
#
# End of epoch 20:
# Time elapsed 10.422s
# -ReconstructionError: 0.668718
# -EnergyCoefficient: 0.399927
# -HeatCapacity: 246.664551
# -WeightSparsity: 0.267319
# -WeightSquare: 6.008708
# -KLDivergence: 0.121539
# -ReverseKLDivergence: 0.430292

# %% [markdown]
# ## More Generative Models
#
# We can easily create a Bernoulli RBM and train it using the functions defined above as follows:

# %%
##### Bernoulli RBM
vis_layer = BernoulliLayer(data.ncols)
hid_layer = BernoulliLayer(num_hidden_units)
rbm = BoltzmannMachine([vis_layer, hid_layer])

# train Bernoulli RBM
train_model(rbm,num_epochs,monte_carlo_steps)
# Out:
# Before training:
# -ReconstructionError: 1.221296
# -EnergyCoefficient: 0.130219
# -HeatCapacity: 0.314381
# -WeightSparsity: 0.336520
# -WeightSquare: 1.585117
# -KLDivergence: 0.170359
# -ReverseKLDivergence: -0.037721
#
# End of epoch 1:
# Time elapsed 8.925s
# -ReconstructionError: 0.890776
# -EnergyCoefficient: 0.279766
# -HeatCapacity: 0.873582
# -WeightSparsity: 0.239493
# -WeightSquare: 28.192406
# -KLDivergence: 0.095151
# -ReverseKLDivergence: 0.168387
#
# End of epoch 2:
# Time elapsed 8.409s
# -ReconstructionError: 0.804468
# -EnergyCoefficient: 0.361324
# -HeatCapacity: 0.733574
# -WeightSparsity: 0.238302
# -WeightSquare: 49.119270
# -KLDivergence: 0.146523
# -ReverseKLDivergence: 0.243259
#
# End of epoch 3:
# Time elapsed 10.252s
# -ReconstructionError: 0.777059
# -EnergyCoefficient: 0.412129
# -HeatCapacity: 5.065194
# -WeightSparsity: 0.233714
# -WeightSquare: 70.679054
# -KLDivergence: 0.051207
# -ReverseKLDivergence: 0.446597
#
# End of epoch 4:
# Time elapsed 8.406s
# -ReconstructionError: 0.746783
# -EnergyCoefficient: 0.299112
# -HeatCapacity: 3.104646
# -WeightSparsity: 0.230903
# -WeightSquare: 93.863022
# -KLDivergence: 0.102817
# -ReverseKLDivergence: 0.260659
#
# End of epoch 5:
# Time elapsed 8.638s
# -ReconstructionError: 0.726400
# -EnergyCoefficient: 0.304500
# -HeatCapacity: 1.833925
# -WeightSparsity: 0.227147
# -WeightSquare: 117.837364
# -KLDivergence: 0.090585
# -ReverseKLDivergence: 0.222912
#
# End of epoch 6:
# Time elapsed 8.411s
# -ReconstructionError: 0.703099
# -EnergyCoefficient: 0.235642
# -HeatCapacity: 2.718934
# -WeightSparsity: 0.221341
# -WeightSquare: 142.144531
# -KLDivergence: 0.050668
# -ReverseKLDivergence: 0.159719
#
# End of epoch 7:
# Time elapsed 10.188s
# -ReconstructionError: 0.694245
# -EnergyCoefficient: 0.320791
# -HeatCapacity: 0.747323
# -WeightSparsity: 0.217083
# -WeightSquare: 169.795410
# -KLDivergence: 0.076740
# -ReverseKLDivergence: 0.282306
#
# End of epoch 8:
# Time elapsed 8.842s
# -ReconstructionError: 0.679194
# -EnergyCoefficient: 0.312774
# -HeatCapacity: 3.917705
# -WeightSparsity: 0.213443
# -WeightSquare: 200.507538
# -KLDivergence: 0.069650
# -ReverseKLDivergence: 0.282287
#
# End of epoch 9:
# Time elapsed 10.916s
# -ReconstructionError: 0.664421
# -EnergyCoefficient: 0.260904
# -HeatCapacity: 1.088546
# -WeightSparsity: 0.210110
# -WeightSquare: 230.246826
# -KLDivergence: 0.053304
# -ReverseKLDivergence: 0.187357
#
# End of epoch 10:
# Time elapsed 8.675s
# -ReconstructionError: 0.656053
# -EnergyCoefficient: 0.258809
# -HeatCapacity: 1.083269
# -WeightSparsity: 0.205391
# -WeightSquare: 260.511383
# -KLDivergence: 0.050818
# -ReverseKLDivergence: 0.182641
#
# End of epoch 11:
# Time elapsed 8.034s
# -ReconstructionError: 0.645894
# -EnergyCoefficient: 0.294232
# -HeatCapacity: 2.436440
# -WeightSparsity: 0.200804
# -WeightSquare: 291.891876
# -KLDivergence: 0.049846
# -ReverseKLDivergence: 0.254191
#
# End of epoch 12:
# Time elapsed 7.897s
# -ReconstructionError: 0.645551
# -EnergyCoefficient: 0.323488
# -HeatCapacity: 0.977802
# -WeightSparsity: 0.197210
# -WeightSquare: 322.897583
# -KLDivergence: 0.053584
# -ReverseKLDivergence: 0.310081
#
# End of epoch 13:
# Time elapsed 7.884s
# -ReconstructionError: 0.631332
# -EnergyCoefficient: 0.268919
# -HeatCapacity: 1.477500
# -WeightSparsity: 0.192862
# -WeightSquare: 354.941010
# -KLDivergence: 0.053447
# -ReverseKLDivergence: 0.202139
#
# End of epoch 14:
# Time elapsed 7.766s
# -ReconstructionError: 0.645319
# -EnergyCoefficient: 0.271384
# -HeatCapacity: 1.403989
# -WeightSparsity: 0.189270
# -WeightSquare: 385.395294
# -KLDivergence: 0.064619
# -ReverseKLDivergence: 0.214576
#
# End of epoch 15:
# Time elapsed 9.153s
# -ReconstructionError: 0.630205
# -EnergyCoefficient: 0.315869
# -HeatCapacity: 2.262074
# -WeightSparsity: 0.187222
# -WeightSquare: 418.956818
# -KLDivergence: 0.054499
# -ReverseKLDivergence: 0.286811
#
# End of epoch 16:
# Time elapsed 11.375s
# -ReconstructionError: 0.621220
# -EnergyCoefficient: 0.284154
# -HeatCapacity: 1.440961
# -WeightSparsity: 0.183238
# -WeightSquare: 449.754211
# -KLDivergence: 0.052836
# -ReverseKLDivergence: 0.224648
#
# End of epoch 17:
# Time elapsed 8.914s
# -ReconstructionError: 0.615392
# -EnergyCoefficient: 0.271069
# -HeatCapacity: 2.231687
# -WeightSparsity: 0.180101
# -WeightSquare: 479.481750
# -KLDivergence: 0.044525
# -ReverseKLDivergence: 0.222524
#
# End of epoch 18:
# Time elapsed 9.557s
# -ReconstructionError: 0.608280
# -EnergyCoefficient: 0.305342
# -HeatCapacity: 1.828177
# -WeightSparsity: 0.176436
# -WeightSquare: 511.435852
# -KLDivergence: 0.045473
# -ReverseKLDivergence: 0.245843
#
# End of epoch 19:
# Time elapsed 10.955s
# -ReconstructionError: 0.617383
# -EnergyCoefficient: 0.322028
# -HeatCapacity: 2.054165
# -WeightSparsity: 0.174247
# -WeightSquare: 544.539429
# -KLDivergence: 0.046439
# -ReverseKLDivergence: 0.303987
#
# End of epoch 20:
# Time elapsed 7.753s
# -ReconstructionError: 0.604872
# -EnergyCoefficient: 0.296016
# -HeatCapacity: 1.893523
# -WeightSparsity: 0.171897
# -WeightSquare: 575.123169
# -KLDivergence: 0.051137
# -ReverseKLDivergence: 0.235049

# %% [markdown]
# Constructing a Bernoulli RBM with L1 regularization is also straightforward in Paysage, using the `add_penalty` method which accepts a dictionary as an input.

# %%
##### Bernoulli RBM with L1 regularizer
vis_layer = BernoulliLayer(data.ncols)
hid_layer = BernoulliLayer(num_hidden_units)
rbm_L1 = BoltzmannMachine([vis_layer, hid_layer])

rbm_L1.connections[0].weights.add_penalty({'matrix': pen.l1_penalty(1e-3)})

# train Bernoulli RBM with L1 regularizer
train_model(rbm_L1,num_epochs,monte_carlo_steps)
# Out:
# Before training:
# -ReconstructionError: 1.226726
# -EnergyCoefficient: 0.130907
# -HeatCapacity: 0.309387
# -WeightSparsity: 0.337285
# -WeightSquare: 1.595394
# -KLDivergence: 0.174636
# -ReverseKLDivergence: -0.034016
#
# End of epoch 1:
# Time elapsed 8.715s
# -ReconstructionError: 0.914609
# -EnergyCoefficient: 0.396909
# -HeatCapacity: 1.061087
# -WeightSparsity: 0.121574
# -WeightSquare: 14.852053
# -KLDivergence: 0.205967
# -ReverseKLDivergence: 0.206238
#
# End of epoch 2:
# Time elapsed 12.942s
# -ReconstructionError: 0.832572
# -EnergyCoefficient: 0.351707
# -HeatCapacity: 0.551750
# -WeightSparsity: 0.111453
# -WeightSquare: 25.571577
# -KLDivergence: 0.067213
# -ReverseKLDivergence: 0.272726
#
# End of epoch 3:
# Time elapsed 9.041s
# -ReconstructionError: 0.790830
# -EnergyCoefficient: 0.309743
# -HeatCapacity: 0.671058
# -WeightSparsity: 0.101826
# -WeightSquare: 35.834209
# -KLDivergence: 0.095809
# -ReverseKLDivergence: 0.220002
#
# End of epoch 4:
# Time elapsed 9.031s
# -ReconstructionError: 0.755846
# -EnergyCoefficient: 0.280296
# -HeatCapacity: 0.717122
# -WeightSparsity: 0.091626
# -WeightSquare: 45.045216
# -KLDivergence: 0.069313
# -ReverseKLDivergence: 0.179477
#
# End of epoch 5:
# Time elapsed 11.076s
# -ReconstructionError: 0.734145
# -EnergyCoefficient: 0.314780
# -HeatCapacity: 0.610197
# -WeightSparsity: 0.086204
# -WeightSquare: 58.034153
# -KLDivergence: 0.064806
# -ReverseKLDivergence: 0.278464
#
# End of epoch 6:
# Time elapsed 8.34s
# -ReconstructionError: 0.719162
# -EnergyCoefficient: 0.293787
# -HeatCapacity: 1.667318
# -WeightSparsity: 0.078734
# -WeightSquare: 69.153755
# -KLDivergence: 0.097856
# -ReverseKLDivergence: 0.250975
#
# End of epoch 7:
# Time elapsed 7.594s
# -ReconstructionError: 0.706430
# -EnergyCoefficient: 0.305851
# -HeatCapacity: 1.320299
# -WeightSparsity: 0.071856
# -WeightSquare: 80.260468
# -KLDivergence: 0.085859
# -ReverseKLDivergence: 0.238404
#
# End of epoch 8:
# Time elapsed 10.583s
# -ReconstructionError: 0.682466
# -EnergyCoefficient: 0.237350
# -HeatCapacity: 1.490180
# -WeightSparsity: 0.067894
# -WeightSquare: 89.107422
# -KLDivergence: 0.071063
# -ReverseKLDivergence: 0.160062
#
# End of epoch 9:
# Time elapsed 8.863s
# -ReconstructionError: 0.680881
# -EnergyCoefficient: 0.241991
# -HeatCapacity: 1.945022
# -WeightSparsity: 0.064024
# -WeightSquare: 99.998169
# -KLDivergence: 0.101378
# -ReverseKLDivergence: 0.163532
#
# End of epoch 10:
# Time elapsed 8.944s
# -ReconstructionError: 0.669019
# -EnergyCoefficient: 0.315518
# -HeatCapacity: 1.233116
# -WeightSparsity: 0.059094
# -WeightSquare: 111.922020
# -KLDivergence: 0.092884
# -ReverseKLDivergence: 0.221745
#
# End of epoch 11:
# Time elapsed 11.396s
# -ReconstructionError: 0.663214
# -EnergyCoefficient: 0.295100
# -HeatCapacity: 1.290168
# -WeightSparsity: 0.056250
# -WeightSquare: 123.754646
# -KLDivergence: 0.092979
# -ReverseKLDivergence: 0.209630
#
# End of epoch 12:
# Time elapsed 9.189s
# -ReconstructionError: 0.647003
# -EnergyCoefficient: 0.269639
# -HeatCapacity: 1.116524
# -WeightSparsity: 0.053505
# -WeightSquare: 133.177490
# -KLDivergence: 0.047454
# -ReverseKLDivergence: 0.208285
#
# End of epoch 13:
# Time elapsed 11.078s
# -ReconstructionError: 0.648368
# -EnergyCoefficient: 0.303222
# -HeatCapacity: 1.121170
# -WeightSparsity: 0.051154
# -WeightSquare: 143.194061
# -KLDivergence: 0.093986
# -ReverseKLDivergence: 0.226056
#
# End of epoch 14:
# Time elapsed 13.713s
# -ReconstructionError: 0.645347
# -EnergyCoefficient: 0.230059
# -HeatCapacity: 1.500671
# -WeightSparsity: 0.049407
# -WeightSquare: 153.125595
# -KLDivergence: 0.051034
# -ReverseKLDivergence: 0.134542
#
# End of epoch 15:
# Time elapsed 9.546s
# -ReconstructionError: 0.643508
# -EnergyCoefficient: 0.273173
# -HeatCapacity: 2.259591
# -WeightSparsity: 0.047431
# -WeightSquare: 161.393082
# -KLDivergence: 0.065793
# -ReverseKLDivergence: 0.207294
#
# End of epoch 16:
# Time elapsed 12.124s
# -ReconstructionError: 0.632433
# -EnergyCoefficient: 0.298330
# -HeatCapacity: 3.188956
# -WeightSparsity: 0.046175
# -WeightSquare: 168.492111
# -KLDivergence: 0.072537
# -ReverseKLDivergence: 0.232789
#
# End of epoch 17:
# Time elapsed 8.566s
# -ReconstructionError: 0.625196
# -EnergyCoefficient: 0.313928
# -HeatCapacity: 3.568847
# -WeightSparsity: 0.044719
# -WeightSquare: 175.538818
# -KLDivergence: 0.048091
# -ReverseKLDivergence: 0.299200
#
# End of epoch 18:
# Time elapsed 8.333s
# -ReconstructionError: 0.619496
# -EnergyCoefficient: 0.245878
# -HeatCapacity: 1.941122
# -WeightSparsity: 0.043813
# -WeightSquare: 183.425659
# -KLDivergence: 0.052628
# -ReverseKLDivergence: 0.153376
#
# End of epoch 19:
# Time elapsed 7.322s
# -ReconstructionError: 0.614269
# -EnergyCoefficient: 0.273806
# -HeatCapacity: 2.644288
# -WeightSparsity: 0.042373
# -WeightSquare: 188.218903
# -KLDivergence: 0.048555
# -ReverseKLDivergence: 0.191661
#
# End of epoch 20:
# Time elapsed 9.424s
# -ReconstructionError: 0.611047
# -EnergyCoefficient: 0.254218
# -HeatCapacity: 3.507017
# -WeightSparsity: 0.041607
# -WeightSquare: 195.234482
# -KLDivergence: 0.063069
# -ReverseKLDivergence: 0.175265

# %% [markdown]
# To define a deep Boltzmann machine (DBM), we just add more layers, and an L1 penalty for every layer.
#
# Recalling the essential trick with layer-wise pre-training to prepare the weights of the DBM, we define a `pretrainer` as an object of the `LayerwisePretrain` class (see code snippet below). This results in a slight modification of the function `train_model`, which we call `train_deep_model`.

# %%
##### Deep Boltzmann Machine
# set up the model
dbm = BoltzmannMachine([BernoulliLayer(data.ncols), # visible layer
                        BernoulliLayer(num_hidden_units), # hidden layer 1
                        BernoulliLayer(num_hidden_units) # hidden layer 2
                       ])

# add an L1 penalty to the weights
for conn in dbm.connections:
    conn.weights.add_penalty({'matrix':pen.l1_penalty(1e-3)})
    
# add pre-training 	
def train_deep_model(model,num_epochs,monte_carlo_steps):
    # make a simple guess for the initial parameters of the model
    model.initialize(data,method='glorot_normal')
    # set SGD rπetrain optimizer
    opt=ADAM_optimizer(1E-2,1.0)
    # pre-train model
    pretrainer=fit.LayerwisePretrain(model,data)
    pretrainer.train(opt, num_epochs, method=fit.pcd, mcsteps=monte_carlo_steps, init_method="glorot_normal")
    # set SGD train optimizer
    opt=ADAM_optimizer(1E-3,1.0)
    # train model
    trainer=fit.SGD(model,data)
    trainer.train(opt,num_epochs,method=fit.pcd,mcsteps=monte_carlo_steps)
# train DBM
train_deep_model(dbm,num_epochs,monte_carlo_steps)
# Out:
# training model 0
#
# Before training:
# -ReconstructionError: 1.225859
# -EnergyCoefficient: 0.132765
# -HeatCapacity: 0.307015
# -WeightSparsity: 0.335363
# -WeightSquare: 1.592832
# -KLDivergence: 0.174117
# -ReverseKLDivergence: -0.032616
#
# End of epoch 1:
# Time elapsed 8.063s
# -ReconstructionError: 0.886865
# -EnergyCoefficient: 0.353134
# -HeatCapacity: 0.493499
# -WeightSparsity: 0.120312
# -WeightSquare: 15.289407
# -KLDivergence: 0.107695
# -ReverseKLDivergence: 0.232846
#
# End of epoch 2:
# Time elapsed 9.009s
# -ReconstructionError: 0.828154
# -EnergyCoefficient: 0.306181
# -HeatCapacity: 0.570803
# -WeightSparsity: 0.110140
# -WeightSquare: 25.235518
# -KLDivergence: 0.110413
# -ReverseKLDivergence: 0.194473
#
# End of epoch 3:
# Time elapsed 10.903s
# -ReconstructionError: 0.783965
# -EnergyCoefficient: 0.305635
# -HeatCapacity: 1.236237
# -WeightSparsity: 0.101250
# -WeightSquare: 36.492725
# -KLDivergence: 0.059668
# -ReverseKLDivergence: 0.245164
#
# End of epoch 4:
# Time elapsed 9.743s
# -ReconstructionError: 0.756995
# -EnergyCoefficient: 0.251563
# -HeatCapacity: 2.275088
# -WeightSparsity: 0.092949
# -WeightSquare: 47.830338
# -KLDivergence: 0.057806
# -ReverseKLDivergence: 0.205692
#
# End of epoch 5:
# Time elapsed 8.063s
# -ReconstructionError: 0.739485
# -EnergyCoefficient: 0.313320
# -HeatCapacity: 1.759671
# -WeightSparsity: 0.085549
# -WeightSquare: 58.444794
# -KLDivergence: 0.126450
# -ReverseKLDivergence: 0.232738
#
# End of epoch 6:
# Time elapsed 11.109s
# -ReconstructionError: 0.713343
# -EnergyCoefficient: 0.313775
# -HeatCapacity: 1.018431
# -WeightSparsity: 0.079292
# -WeightSquare: 69.823387
# -KLDivergence: 0.043591
# -ReverseKLDivergence: 0.262930
#
# End of epoch 7:
# Time elapsed 8.458s
# -ReconstructionError: 0.698254
# -EnergyCoefficient: 0.231092
# -HeatCapacity: 1.661505
# -WeightSparsity: 0.073179
# -WeightSquare: 80.368286
# -KLDivergence: 0.045603
# -ReverseKLDivergence: 0.161177
#
# End of epoch 8:
# Time elapsed 9.37s
# -ReconstructionError: 0.687796
# -EnergyCoefficient: 0.326736
# -HeatCapacity: 1.285824
# -WeightSparsity: 0.068707
# -WeightSquare: 93.479782
# -KLDivergence: 0.082381
# -ReverseKLDivergence: 0.269980
#
# End of epoch 9:
# Time elapsed 10.701s
# -ReconstructionError: 0.683628
# -EnergyCoefficient: 0.328092
# -HeatCapacity: 2.817249
# -WeightSparsity: 0.062416
# -WeightSquare: 101.945900
# -KLDivergence: 0.060188
# -ReverseKLDivergence: 0.292482
#
# End of epoch 10:
# Time elapsed 10.108s
# -ReconstructionError: 0.661716
# -EnergyCoefficient: 0.242316
# -HeatCapacity: 1.255128
# -WeightSparsity: 0.059056
# -WeightSquare: 114.346107
# -KLDivergence: 0.062036
# -ReverseKLDivergence: 0.168707
#
# End of epoch 11:
# Time elapsed 12.012s
# -ReconstructionError: 0.656906
# -EnergyCoefficient: 0.259336
# -HeatCapacity: 1.865707
# -WeightSparsity: 0.056361
# -WeightSquare: 125.207497
# -KLDivergence: 0.048663
# -ReverseKLDivergence: 0.212296
#
# End of epoch 12:
# Time elapsed 10.275s
# -ReconstructionError: 0.650826
# -EnergyCoefficient: 0.275015
# -HeatCapacity: 1.716261
# -WeightSparsity: 0.053180
# -WeightSquare: 135.179581
# -KLDivergence: 0.063558
# -ReverseKLDivergence: 0.174034
#
# End of epoch 13:
# Time elapsed 8.869s
# -ReconstructionError: 0.648619
# -EnergyCoefficient: 0.256367
# -HeatCapacity: 2.457054
# -WeightSparsity: 0.051426
# -WeightSquare: 144.777817
# -KLDivergence: 0.021903
# -ReverseKLDivergence: 0.194761
#
# End of epoch 14:
# Time elapsed 11.683s
# -ReconstructionError: 0.645417
# -EnergyCoefficient: 0.252058
# -HeatCapacity: 3.787866
# -WeightSparsity: 0.049482
# -WeightSquare: 155.399719
# -KLDivergence: 0.077151
# -ReverseKLDivergence: 0.180856
#
# End of epoch 15:
# Time elapsed 8.989s
# -ReconstructionError: 0.632375
# -EnergyCoefficient: 0.276320
# -HeatCapacity: 2.632245
# -WeightSparsity: 0.047486
# -WeightSquare: 162.992737
# -KLDivergence: 0.043926
# -ReverseKLDivergence: 0.216246
#
# End of epoch 16:
# Time elapsed 9.134s
# -ReconstructionError: 0.635591
# -EnergyCoefficient: 0.272870
# -HeatCapacity: 1.652110
# -WeightSparsity: 0.045597
# -WeightSquare: 170.253479
# -KLDivergence: 0.046628
# -ReverseKLDivergence: 0.201066
#
# End of epoch 17:
# Time elapsed 10.424s
# -ReconstructionError: 0.627806
# -EnergyCoefficient: 0.314942
# -HeatCapacity: 2.668448
# -WeightSparsity: 0.044270
# -WeightSquare: 176.568008
# -KLDivergence: 0.070615
# -ReverseKLDivergence: 0.271274
#
# End of epoch 18:
# Time elapsed 10.457s
# -ReconstructionError: 0.613801
# -EnergyCoefficient: 0.266050
# -HeatCapacity: 1.096513
# -WeightSparsity: 0.043606
# -WeightSquare: 182.529404
# -KLDivergence: 0.035303
# -ReverseKLDivergence: 0.205823
#
# End of epoch 19:
# Time elapsed 8.678s
# -ReconstructionError: 0.619264
# -EnergyCoefficient: 0.265400
# -HeatCapacity: 1.906448
# -WeightSparsity: 0.042218
# -WeightSquare: 190.960892
# -KLDivergence: 0.045974
# -ReverseKLDivergence: 0.202638
#
# End of epoch 20:
# Time elapsed 9.649s
# -ReconstructionError: 0.614404
# -EnergyCoefficient: 0.283478
# -HeatCapacity: 3.291147
# -WeightSparsity: 0.041563
# -WeightSquare: 198.184875
# -KLDivergence: 0.072271
# -ReverseKLDivergence: 0.200912
#
# training model 1
#
# Before training:
# -ReconstructionError: 1.782010
# -EnergyCoefficient: 0.613856
# -HeatCapacity: 0.421690
# -WeightSparsity: 0.337216
# -WeightSquare: 1.000896
# -KLDivergence: 0.556717
# -ReverseKLDivergence: 0.546062
#
# End of epoch 1:
# Time elapsed 5.954s
# -ReconstructionError: 0.970622
# -EnergyCoefficient: 0.251716
# -HeatCapacity: 9.257565
# -WeightSparsity: 0.165859
# -WeightSquare: 3.088478
# -KLDivergence: 0.118420
# -ReverseKLDivergence: 0.074763
#
# End of epoch 2:
# Time elapsed 5.931s
# -ReconstructionError: 0.917425
# -EnergyCoefficient: 0.296439
# -HeatCapacity: 8.083158
# -WeightSparsity: 0.165730
# -WeightSquare: 4.193359
# -KLDivergence: 0.206989
# -ReverseKLDivergence: 0.067271
#
# End of epoch 3:
# Time elapsed 5.972s
# -ReconstructionError: 0.879283
# -EnergyCoefficient: 0.260505
# -HeatCapacity: 13.939301
# -WeightSparsity: 0.164987
# -WeightSquare: 5.215529
# -KLDivergence: 0.134858
# -ReverseKLDivergence: 0.051013
#
# End of epoch 4:
# Time elapsed 7.873s
# -ReconstructionError: 0.853280
# -EnergyCoefficient: 0.345485
# -HeatCapacity: 10.336225
# -WeightSparsity: 0.163651
# -WeightSquare: 6.234799
# -KLDivergence: 0.189706
# -ReverseKLDivergence: 0.097077
#
# End of epoch 5:
# Time elapsed 5.948s
# -ReconstructionError: 0.839912
# -EnergyCoefficient: 0.348266
# -HeatCapacity: 7.958555
# -WeightSparsity: 0.162790
# -WeightSquare: 7.329842
# -KLDivergence: 0.242057
# -ReverseKLDivergence: 0.094824
#
# End of epoch 6:
# Time elapsed 5.913s
# -ReconstructionError: 0.821002
# -EnergyCoefficient: 0.373140
# -HeatCapacity: 6.161927
# -WeightSparsity: 0.160192
# -WeightSquare: 8.609473
# -KLDivergence: 0.234327
# -ReverseKLDivergence: 0.107573
#
# End of epoch 7:
# Time elapsed 5.887s
# -ReconstructionError: 0.827001
# -EnergyCoefficient: 0.343241
# -HeatCapacity: 2.820802
# -WeightSparsity: 0.157256
# -WeightSquare: 9.744617
# -KLDivergence: 0.234299
# -ReverseKLDivergence: 0.118495
#
# End of epoch 8:
# Time elapsed 5.908s
# -ReconstructionError: 0.786731
# -EnergyCoefficient: 0.361749
# -HeatCapacity: 4.855702
# -WeightSparsity: 0.154382
# -WeightSquare: 10.980479
# -KLDivergence: 0.262638
# -ReverseKLDivergence: 0.159685
#
# End of epoch 9:
# Time elapsed 7.889s
# -ReconstructionError: 0.784708
# -EnergyCoefficient: 0.426950
# -HeatCapacity: 8.713709
# -WeightSparsity: 0.148628
# -WeightSquare: 12.005122
# -KLDivergence: 0.304920
# -ReverseKLDivergence: 0.228100
#
# End of epoch 10:
# Time elapsed 5.844s
# -ReconstructionError: 0.784218
# -EnergyCoefficient: 0.374193
# -HeatCapacity: 4.509809
# -WeightSparsity: 0.141906
# -WeightSquare: 13.104755
# -KLDivergence: 0.275922
# -ReverseKLDivergence: 0.158169
#
# End of epoch 11:
# Time elapsed 5.809s
# -ReconstructionError: 0.786214
# -EnergyCoefficient: 0.444957
# -HeatCapacity: 3.055124
# -WeightSparsity: 0.134109
# -WeightSquare: 14.411225
# -KLDivergence: 0.300669
# -ReverseKLDivergence: 0.210116
#
# End of epoch 12:
# Time elapsed 5.826s
# -ReconstructionError: 0.755947
# -EnergyCoefficient: 0.401181
# -HeatCapacity: 12.326402
# -WeightSparsity: 0.125122
# -WeightSquare: 15.484821
# -KLDivergence: 0.265311
# -ReverseKLDivergence: 0.206769
#
# End of epoch 13:
# Time elapsed 7.931s
# -ReconstructionError: 0.744494
# -EnergyCoefficient: 0.441459
# -HeatCapacity: 2.140839
# -WeightSparsity: 0.116699
# -WeightSquare: 16.594969
# -KLDivergence: 0.322871
# -ReverseKLDivergence: 0.192644
#
# End of epoch 14:
# Time elapsed 5.921s
# -ReconstructionError: 0.733671
# -EnergyCoefficient: 0.408254
# -HeatCapacity: 4.020281
# -WeightSparsity: 0.111262
# -WeightSquare: 17.852243
# -KLDivergence: 0.272777
# -ReverseKLDivergence: 0.145372
#
# End of epoch 15:
# Time elapsed 5.905s
# -ReconstructionError: 0.735633
# -EnergyCoefficient: 0.341714
# -HeatCapacity: 4.742708
# -WeightSparsity: 0.106312
# -WeightSquare: 19.016191
# -KLDivergence: 0.224182
# -ReverseKLDivergence: 0.103577
#
# End of epoch 16:
# Time elapsed 5.811s
# -ReconstructionError: 0.730585
# -EnergyCoefficient: 0.416842
# -HeatCapacity: 3.964163
# -WeightSparsity: 0.102549
# -WeightSquare: 20.157705
# -KLDivergence: 0.273201
# -ReverseKLDivergence: 0.212527
#
# End of epoch 17:
# Time elapsed 5.814s
# -ReconstructionError: 0.739197
# -EnergyCoefficient: 0.416583
# -HeatCapacity: 2.784839
# -WeightSparsity: 0.098605
# -WeightSquare: 21.280230
# -KLDivergence: 0.266681
# -ReverseKLDivergence: 0.237638
#
# End of epoch 18:
# Time elapsed 7.928s
# -ReconstructionError: 0.716084
# -EnergyCoefficient: 0.394711
# -HeatCapacity: 3.539481
# -WeightSparsity: 0.094895
# -WeightSquare: 22.123554
# -KLDivergence: 0.265323
# -ReverseKLDivergence: 0.222040
#
# End of epoch 19:
# Time elapsed 5.909s
# -ReconstructionError: 0.727332
# -EnergyCoefficient: 0.433071
# -HeatCapacity: 3.066729
# -WeightSparsity: 0.093571
# -WeightSquare: 22.541664
# -KLDivergence: 0.253128
# -ReverseKLDivergence: 0.216611
#
# End of epoch 20:
# Time elapsed 5.74s
# -ReconstructionError: 0.702818
# -EnergyCoefficient: 0.440237
# -HeatCapacity: 2.784688
# -WeightSparsity: 0.096645
# -WeightSquare: 23.122284
# -KLDivergence: 0.277598
# -ReverseKLDivergence: 0.247642
#
# Before training:
# -ReconstructionError: 0.794238
# -EnergyCoefficient: 0.340186
# -HeatCapacity: 2.496956
# -WeightSparsity: 0.041563
# -WeightSquare: 198.184875
# -KLDivergence: 0.140352
# -ReverseKLDivergence: 0.233629
#
# End of epoch 1:
# Time elapsed 17.428s
# -ReconstructionError: 0.736925
# -EnergyCoefficient: 0.217571
# -HeatCapacity: 1.955604
# -WeightSparsity: 0.041458
# -WeightSquare: 204.223862
# -KLDivergence: 0.032184
# -ReverseKLDivergence: 0.112378
#
# End of epoch 2:
# Time elapsed 12.952s
# -ReconstructionError: 0.733553
# -EnergyCoefficient: 0.213720
# -HeatCapacity: 1.820713
# -WeightSparsity: 0.041018
# -WeightSquare: 206.599854
# -KLDivergence: 0.012656
# -ReverseKLDivergence: 0.110041
#
# End of epoch 3:
# Time elapsed 13.807s
# -ReconstructionError: 0.736906
# -EnergyCoefficient: 0.199493
# -HeatCapacity: 2.020200
# -WeightSparsity: 0.040422
# -WeightSquare: 207.926285
# -KLDivergence: 0.028613
# -ReverseKLDivergence: 0.087638
#
# End of epoch 4:
# Time elapsed 11.213s
# -ReconstructionError: 0.732518
# -EnergyCoefficient: 0.196341
# -HeatCapacity: 2.540084
# -WeightSparsity: 0.039910
# -WeightSquare: 209.752808
# -KLDivergence: 0.016672
# -ReverseKLDivergence: 0.089888
#
# End of epoch 5:
# Time elapsed 12.021s
# -ReconstructionError: 0.731844
# -EnergyCoefficient: 0.211976
# -HeatCapacity: 2.038225
# -WeightSparsity: 0.039261
# -WeightSquare: 210.386902
# -KLDivergence: 0.021853
# -ReverseKLDivergence: 0.108940
#
# End of epoch 6:
# Time elapsed 11.913s
# -ReconstructionError: 0.729327
# -EnergyCoefficient: 0.199497
# -HeatCapacity: 1.655728
# -WeightSparsity: 0.038745
# -WeightSquare: 211.537903
# -KLDivergence: 0.028235
# -ReverseKLDivergence: 0.092531
#
# End of epoch 7:
# Time elapsed 12.712s
# -ReconstructionError: 0.725539
# -EnergyCoefficient: 0.194386
# -HeatCapacity: 2.090084
# -WeightSparsity: 0.038223
# -WeightSquare: 212.547104
# -KLDivergence: 0.028507
# -ReverseKLDivergence: 0.090705
#
# End of epoch 8:
# Time elapsed 13.899s
# -ReconstructionError: 0.714830
# -EnergyCoefficient: 0.183526
# -HeatCapacity: 1.972996
# -WeightSparsity: 0.037756
# -WeightSquare: 213.885071
# -KLDivergence: 0.018798
# -ReverseKLDivergence: 0.075237
#
# End of epoch 9:
# Time elapsed 12.124s
# -ReconstructionError: 0.711893
# -EnergyCoefficient: 0.217543
# -HeatCapacity: 2.857501
# -WeightSparsity: 0.037324
# -WeightSquare: 215.281601
# -KLDivergence: 0.009259
# -ReverseKLDivergence: 0.110789
#
# End of epoch 10:
# Time elapsed 14.954s
# -ReconstructionError: 0.706486
# -EnergyCoefficient: 0.203813
# -HeatCapacity: 3.243788
# -WeightSparsity: 0.036784
# -WeightSquare: 216.125443
# -KLDivergence: 0.011201
# -ReverseKLDivergence: 0.093430
#
# End of epoch 11:
# Time elapsed 10.258s
# -ReconstructionError: 0.702414
# -EnergyCoefficient: 0.196484
# -HeatCapacity: 1.623196
# -WeightSparsity: 0.036351
# -WeightSquare: 217.417496
# -KLDivergence: 0.023375
# -ReverseKLDivergence: 0.096264
#
# End of epoch 12:
# Time elapsed 14.012s
# -ReconstructionError: 0.699737
# -EnergyCoefficient: 0.207038
# -HeatCapacity: 1.649864
# -WeightSparsity: 0.035826
# -WeightSquare: 218.566330
# -KLDivergence: 0.017674
# -ReverseKLDivergence: 0.111628
#
# End of epoch 13:
# Time elapsed 12.68s
# -ReconstructionError: 0.691683
# -EnergyCoefficient: 0.192897
# -HeatCapacity: 2.149466
# -WeightSparsity: 0.035447
# -WeightSquare: 220.087631
# -KLDivergence: 0.011873
# -ReverseKLDivergence: 0.097778
#
# End of epoch 14:
# Time elapsed 12.302s
# -ReconstructionError: 0.689257
# -EnergyCoefficient: 0.214502
# -HeatCapacity: 1.606261
# -WeightSparsity: 0.034941
# -WeightSquare: 221.190659
# -KLDivergence: 0.014178
# -ReverseKLDivergence: 0.117084
#
# End of epoch 15:
# Time elapsed 11.024s
# -ReconstructionError: 0.687445
# -EnergyCoefficient: 0.195662
# -HeatCapacity: 1.396793
# -WeightSparsity: 0.034528
# -WeightSquare: 222.700699
# -KLDivergence: 0.018757
# -ReverseKLDivergence: 0.090735
#
# End of epoch 16:
# Time elapsed 11.207s
# -ReconstructionError: 0.682299
# -EnergyCoefficient: 0.201536
# -HeatCapacity: 1.789064
# -WeightSparsity: 0.034141
# -WeightSquare: 224.061798
# -KLDivergence: 0.009127
# -ReverseKLDivergence: 0.106316
#
# End of epoch 17:
# Time elapsed 12.899s
# -ReconstructionError: 0.681054
# -EnergyCoefficient: 0.213586
# -HeatCapacity: 1.573769
# -WeightSparsity: 0.033775
# -WeightSquare: 225.385208
# -KLDivergence: 0.008847
# -ReverseKLDivergence: 0.118301
#
# End of epoch 18:
# Time elapsed 11.781s
# -ReconstructionError: 0.679758
# -EnergyCoefficient: 0.219780
# -HeatCapacity: 1.270496
# -WeightSparsity: 0.033511
# -WeightSquare: 227.491714
# -KLDivergence: 0.016941
# -ReverseKLDivergence: 0.124374
#
# End of epoch 19:
# Time elapsed 14.565s
# -ReconstructionError: 0.679300
# -EnergyCoefficient: 0.215700
# -HeatCapacity: 1.026478
# -WeightSparsity: 0.033119
# -WeightSquare: 228.617142
# -KLDivergence: 0.023105
# -ReverseKLDivergence: 0.129178
#
# End of epoch 20:
# Time elapsed 12.264s
# -ReconstructionError: 0.674673
# -EnergyCoefficient: 0.223145
# -HeatCapacity: 1.051281
# -WeightSparsity: 0.032808
# -WeightSquare: 230.193237
# -KLDivergence: 0.025249
# -ReverseKLDivergence: 0.129881

# %% [markdown]
# ## Visualizing the MNIST Dataset
#
# Let us look at a couple of random examples to get an idea how the data we are dealing with actually looks like.
#
# To do this, we define the function  `plot_image_grid()`.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.gridspec as gs
import matplotlib.cm as cm
import seaborn as sns

# make sure the plots are shown in the notebook

def plot_image_grid(image_array, shape, vmin=0, vmax=1, cmap=cm.gray_r, row_titles=None):
    array = be.to_numpy_array(image_array)
    nrows, ncols = array.shape[:-1]
    f = plt.figure(figsize=(2*ncols, 2*nrows))
    grid = gs.GridSpec(nrows, ncols)
    axes = [[plt.subplot(grid[i,j]) for j in range(ncols)] for i in range(nrows)]
    for i in range(nrows):
        for j in range(ncols):
            sns.heatmap(np.reshape(array[i][j], shape),
                ax=axes[i][j], cmap=cmap, cbar=False, vmin=vmin, vmax=vmax)
            axes[i][j].set(yticks=[])
            axes[i][j].set(xticks=[])

    if row_titles is not None:
        for i in range(nrows):
            axes[i][0].set_ylabel(row_titles[i], fontsize=36)
            
    plt.tight_layout()
    plt.show(f)
    plt.close(f)
    

image_shape = (28, 28) # 28x28 = 784 pixels in every image
num_to_plot = 8 # of data points to plot

examples = data.get(mode='train') # shape (batch_size, 784)

example_plot = plot_image_grid(np.expand_dims(examples[:num_to_plot], 0), 
                               image_shape, vmin=0, vmax=1)

# %% [markdown]
# ### Reconstructions
#
# Having trained our models, let us see how they perform by computing some reconstructions from the validation data.
#
# Recall that a reconstruction ${\bf v'}$ of a given data point ${\bf x}$ is computed in two steps: (i) we fix the visible layer ${\bf v}={\bf x}$ to be the data, and use MC sampling to find the state of the hidden layer ${\bf h}$ which maximizes the probability distribution $p({\bf h}\vert{\bf v})$, (ii) fixing the same obtained state ${\bf h}$, we find the reconstruction of the visible layer ${\bf v'}$ which maximizes the probability $p({\bf v'}\vert{\bf h})$. In the case of a DBM, the forward pass continues until we reach the last of the hidden layers, and the backward pass goes in reverse.
#
# To compute reconstructions, we define a MC `sampler` based on the trained `model`. The stating point form the MC sampler is set using the `set_state()` method. To compute reconstructions, we need to keep the probability distribution encoded in the `model` fixed which is done with the help of the `deterministic_iteration` function method, which takes the number of weights `num_weights` in the model, and the state of the sampler `sampler.state` as required arguments. We can combine these steps in the function `compute_reconstructions`.

# %%
##### compute reconstructions
def compute_reconstructions(model, data):
    """
    Computes reconstructions of the input data.
    Input v -> h -> v' (one pass up one pass down)
    
    Args:
        model: a model
        data: a tensor of shape (num_samples, num_visible_units)

    Returns:
        tensor of shape (num_samples, num_visible_units)
    
    """
    recons = model.compute_reconstructions(data).get_visible()
    return be.to_numpy_array(recons)

examples = data.get(mode='validate') # shape (batch_size, 784)
data.reset_generator(mode='validate') # reset the generator to the beginning of the validation set

hopfield_reconstructions = compute_reconstructions(hopfield, examples[:num_to_plot])
rbm_reconstructions = compute_reconstructions(rbm, examples[:num_to_plot])
rbm_L1_reconstructions = compute_reconstructions(rbm_L1, examples[:num_to_plot])
dbm_reconstructions = compute_reconstructions(dbm, examples[:num_to_plot])

reconstruction_plot = plot_image_grid(
    np.array([examples[:num_to_plot], 
                 hopfield_reconstructions, 
                 rbm_reconstructions, 
                 rbm_L1_reconstructions,
                 dbm_reconstructions]), 
    image_shape, vmin=0, vmax=1, row_titles=["Data", "Hopfield", "RBM", "RBM (L1)", "DBM"])

# %% [markdown]
# ### Fantasy Particles
#
# Once we have the trained models ready, we can use MC to draw samples from the corresponding probability distributions, called "fantasy particles". To this end let us draw a `random_sample` from the validation data, and compute the `model_state`. Next, we define a MC `sampler` based on the `model`, and set its state to `model_state`. To compute the fantasy particles, we do layer-wise Gibbs sampling for a total of `n_steps` equilibration steps. The last step (controlled by the boolean `mean_field`) is a final mean-field iteration.

# %%
def compute_fantasy_particles(model,num_fantasy,num_steps,mean_field=True):
    """
    Draws samples from the model using Gibbs sampling Markov Chain Monte Carlo .
    Starts from randomly initialized points. 

    Args:
        model: a model
        data: a tensor of shape (num_samples, num_visible_units)
        num_steps (int): the number of update steps
        mean_field (bool; optional): run a final mean field step to compute probabilities

    Returns:
        tensor of shape (num_samples, num_visible_units)
    
    """
    schedule = schedules.Linear(initial=1.0, delta = 1 / (num_steps-1))
    fantasy = samplers.SequentialMC.generate_fantasy_state(model,
                                                           num_fantasy,
                                                           num_steps,
                                                           schedule=schedule,
                                                           beta_std=0.0,
                                                           beta_momentum=0.0)
    if mean_field:
        fantasy = model.mean_field_iteration(1, fantasy)
    fantasy_particles = fantasy.get_visible()        
    return be.to_numpy_array(fantasy_particles)

examples = data.get(mode='validate') # shape (batch_size, 784)
data.reset_generator(mode='validate') # reset the generator to the beginning of the validation set

hopfield_fantasy = compute_fantasy_particles(hopfield, num_to_plot, 100, mean_field=False)
rbm_fantasy = compute_fantasy_particles(rbm, num_to_plot, 100, mean_field=False)
rbm_L1_fantasy = compute_fantasy_particles(rbm_L1, num_to_plot, 100, mean_field=False)
dbm_fantasy = compute_fantasy_particles(dbm, num_to_plot, 100, mean_field=False)

fantasy_plot = plot_image_grid(
    np.array([hopfield_fantasy, 
                 rbm_fantasy, 
                 rbm_L1_fantasy,
                 dbm_fantasy]), 
    image_shape, vmin=0, vmax=1, row_titles=["Hopfield", "RBM", "RBM (L1)", "DBM"])

# %% [markdown]
# ### De-noising Images
#
# One can use generative models to reduce the noise in images (de-noising). Let us randomly flip a fraction, `fraction_to_flip`, of the black & white bits in the validation data, and use the models defined above to reconstruct (de-noise) the digit images:

# %%
##### denoise MNIST images
# get validation data
examples = data.get(mode='validate') # shape (batch_size, 784)
# reset data generator to beginning of the validation set
data.reset_generator(mode='validate') 

# add some noise to the examples by randomly flipping some pixels 0 -> 1 and 1 -> 0
fraction_to_flip=0.15
# create flipping mask
flip_mask=be.rand_like(examples) < fraction_to_flip
# compute noisy data
noisy_data=(1-flip_mask) * examples + flip_mask * (1 - examples)

# define number of digits to display
num_to_display=8
# compute de-noised images
hopfield_denoised=compute_reconstructions(hopfield,noisy_data[:num_to_display])
rbm_denoised=compute_reconstructions(rbm,noisy_data[:num_to_display])
rbm_L1_denoised=compute_reconstructions(rbm_L1,noisy_data[:num_to_display])
dbm_denoised=compute_reconstructions(dbm,noisy_data[:num_to_display])

denoising_plot = plot_image_grid(
    np.array([examples[:num_to_plot], 
                 noisy_data[:num_to_plot], 
                 hopfield_denoised, 
                 rbm_denoised, 
                 rbm_L1_denoised,
                 dbm_denoised]), 
    image_shape, vmin=0, vmax=1, row_titles=["Data", "Noisy", "Hopfield", "RBM", "RBM (L1)", "DBM"])

# %% [markdown]
# ### Weight Visualization
#
# Let us open up the black box of our generative models now. Below, we show the features learned by the weights of the different models.

# %%
# plot the weights of the hopfield model
hopfield_weights = plot_image_grid(
    be.reshape(hopfield.connections[0].weights.W(trans=True)[:25], (5,5,784)), 
    image_shape, 
    vmin=be.tmin(hopfield.connections[0].weights.W()), 
    vmax=be.tmax(hopfield.connections[0].weights.W()),
    cmap=cm.seismic)

# %%
# plot the weights of the RBM
rbm_weights = plot_image_grid(
    be.reshape(rbm.connections[0].weights.W(trans=True)[:25], (5,5,784)), 
    image_shape, 
    vmin=be.tmin(rbm.connections[0].weights.W()), 
    vmax=be.tmax(rbm.connections[0].weights.W()),
    cmap=cm.seismic)

# %%
# plot the weights of the L1 regularized RBM
rbmL1_weights = plot_image_grid(
    be.reshape(rbm_L1.connections[0].weights.W(trans=True)[:25], (5,5,784)), 
    image_shape, 
    vmin=be.tmin(rbm_L1.connections[0].weights.W()), 
    vmax=be.tmax(rbm_L1.connections[0].weights.W()),
    cmap=cm.seismic)

# %%
# plot the weights of the first layer of the dbm
dbm_weights = plot_image_grid(
    be.reshape(dbm.connections[0].weights.W(trans=True)[:25], (5,5,784)), 
    image_shape, 
    vmin=be.tmin(dbm.connections[0].weights.W()), 
    vmax=be.tmax(dbm.connections[0].weights.W()),
    cmap=cm.seismic)

# %%
data.close() # close the HDF5 store with the MNIST dataset

# %% [markdown]
# ## Exercises
#
# * Try increasing/decreasing the number of hidden units and study systematically how the performance of the different models changes.
# * Look up Paysage's documentation and study the performance for various SGD optimizers.
